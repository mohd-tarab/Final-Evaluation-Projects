# %% [markdown]
# # Problem Defination

# %% [raw]
# IBM_HR_Attrition_Rate_Analytics:-
# Problem- Attrition in HR
# Problem Statement- Attrition is the common problem facced by every copany, the loss of employee cost companies. As time, money and effors has been decicated to an employee/ employees.
# ----How does HR Analytics help in analyzing Attriation.
# ...To find the reasons behind Attrition.
# ...To Decribe how it afftects the Attrition.
# ...What measures should be taken inorder to minimise the attrition rate.

# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('IBM_HR_Attrition_Rate_Analytics.csv')

# %%
df.head(25)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
#displaying all columns in the data set.

# %%
pd.set_option('display.max_columns', 40)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["EmployeeCount"].unique()
# Out:
# array([1], dtype=int64)

# %% [markdown]
# Employee Count is one and it is not effecting the dataframe, it can be removed.

# %%
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.count()
# Out:
# Age                         1470
# Attrition                   1470
# BusinessTravel              1470
# DailyRate                   1470
# Department                  1470
# DistanceFromHome            1470
# Education                   1470
# EducationField              1470
# EmployeeCount               1470
# EmployeeNumber              1470
# EnvironmentSatisfaction     1470
# Gender                      1470
# HourlyRate                  1470
# JobInvolvement              1470
# JobLevel                    1470
# JobRole                     1470
# JobSatisfaction             1470
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# NumCompaniesWorked          1470
# Over18                      1470
# OverTime                    1470
# PercentSalaryHike           1470
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# StockOptionLevel            1470
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# it looks like that the data set has some outliers. some places theree are few of them while others like daily rate ans such has more, which needs treatment.

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df==" "
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %% [markdown]
# So there are no null values.

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### UniVariate Analysis

# %%
ax=sns.countplot(x='Attrition',data=df)
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# 237 employess left the organisation.

# %%
print(237/1470*100 ,'is the % of Attiration')
# Out:
# 16.122448979591837 is the % of Attiration

# %%
ax=sns.countplot(x='BusinessTravel',data=df)
print(df['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# There are 150 employees who rarly travel, and 277 of them who are frequent travelers
# And 1043 of them rearly travel

# %%
ax=sns.countplot(x='Department',data=df)
print(df['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# there are 961 employees in RND department and 446 in sales and least in HR with 63

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='EducationField',data=df)
print(df['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# there are 606 employees with life science education feild, leading after medical with 464, least with HR

# %%
ax=sns.countplot(x='Gender',data=df)
print(df['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
print("There are", (882-588), "more male employees than females. ")
# Out:
# There are 294 more male employees than females.

# %%
plt.figure(figsize = (32,29))
sns.countplot(x='JobRole',data=df)
print(df['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# there are 326 for Sales Executive job role , and for HR there are 52 being the lowest number of employees in the job role.

# %%
sns.countplot(x='MaritalStatus',data=df)
print(df['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# There are 673 people married, 470 being single and 327 divorced.

# %%
sns.countplot(x='Over18',data=df)
print(df['Over18'].value_counts())
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# Yes there are every employee being above 18 years of age.

# %%
sns.countplot(x='OverTime',data=df)
print(df['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# most(1054) employees not do over time as they don't like it that much.

# %% [markdown]
# ## MultiVariate Analysis

# %%
ax=sns.catplot(x='Attrition', y='Age',data=df)

# %% [markdown]
# here we see an inverse relationship with the age, the employees with more age tend to stay, where youngsters are towards switching the company.

# %%
ax=plt.subplots()
df['Attrition'].value_counts().plot.line()
df['BusinessTravel'].value_counts().plot.bar()
plt.show()

# %%
ax=sns.countplot(x='BusinessTravel', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# The attrition rate of employees who travel rarely is much more then thoes of who travel or frequent travellers.

# %% [raw]
# for i in df:
#     print(i)
#     plt.figure(figsize = (32,29))
#     print(sns.countplot(x=i, hue="Attrition", data=df))
#     plt.show()

# %%
sns.catplot(data=df, x="Attrition", y="DailyRate")
plt.show()

# %% [markdown]
# there is attrition at every point of Daily Rate

# %%
ax=sns.countplot(x='Department', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# RnD has more atteration rate, then sales and lastly is H.R

# %%
ax=sns.catplot(x='Attrition', y='DistanceFromHome', kind='swarm', data=df)
plt.show()

# %% [markdown]
# here we see those who are coming from below 10 km have attrition rate, rather than those who are coming from far away

# %%
ax=sns.countplot(x='Education', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# those with education of 3 years tend to have more attrition rate then 4 years.

# %%
plt.figure(figsize=(15,10))
ax=sns.countplot(x='EducationField', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Employees of Life Sciences tend to have more attrition rate, then comes medical, coming after marketing and then technical and lastly HR

# %%
ax=sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# the relationship datisfaction doesnot show much, tho those having less relationship satisfaction tend to stay a bit more.

# %%
ax=sns.countplot(x='StockOptionLevel', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# StockOptionLevel is ment for senior employees in many companies, hence it also dosn't show any significant relationship.

# %%
ax=sns.lineplot(x='Attrition', y='TotalWorkingYears', data=df)
plt.show()

# %% [markdown]
# New joiners tend to leave company more

# %%
ax=sns.countplot(x='TrainingTimesLastYear', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Here we see that those who are getting training twice and thrice a year are likely to leave the company.

# %%
ax=sns.countplot(x='WorkLifeBalance', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Employees those have given 3 points for work life balance tend to leave the company.

# %%
ax=sns.lineplot(x='Attrition', y='YearsAtCompany', data=df)
plt.show()

# %% [markdown]
# those having less time than 5 yrs then to have attrition rate

# %%
ax=sns.lineplot(x='Attrition', y='YearsInCurrentRole', data=df)
plt.show()

# %% [markdown]
# if an employee is in a particular role for less than3 years have high attrition rate

# %%
plt.figure(figsize=(15,10))
ax=sns.countplot(x='YearsSinceLastPromotion', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# those who are new employees or recent joiners tend to have more attrition rate.

# %%
plt.figure(figsize=(15,10))
ax=sns.countplot(x='YearsWithCurrManager', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# those having 2 yrs of same manager are having high attrition rate

# %%
ax=sns.countplot(x='Gender', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# males tend to have moreattrition rate then females.

# %%
sns.catplot(x="Gender", y="WorkLifeBalance", hue="Attrition", kind="bar", data=df)
plt.show()

# %% [markdown]
# both males and females who have work-life balance above 2.5 have some what equal attrition rate.

# %%
sns.catplot(x="Gender", y="DistanceFromHome", hue="Attrition", kind="bar", data=df)
plt.show()

# %% [markdown]
# Females who are coming from far away have more attition rate than men.

# %%
sns.catplot(x="Gender", y="Age", hue="Attrition", kind="bar", data=df)
plt.show()

# %% [markdown]
# one the basis of age males have a bit more attrition rate compared to females

# %%
plt.figure(figsize=(25,10))
sns.catplot(x="Department", y="TotalWorkingYears", hue="Attrition", kind="bar", data=df)
plt.show()

# %% [markdown]
# in this case if department, employees with 8+ in sales and RnD, and 6.5+in H.R tend to have attrition Rate

# %% [markdown]
# ## Chcking the distribution of Continous value columns.

# %%
df_c=df[[ 'HourlyRate','MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'PercentSalaryHike','TotalWorkingYears']].copy()

# %%
df_c
# Out:
#       HourlyRate  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0             94           5993        19479                   8
# 1             61           5130        24907                   1
# 2             92           2090         2396                   6
# 3             56           2909        23159                   1
# 4             40           3468        16632                   9
# ...          ...            ...          ...                 ...
# 1465          41           2571        12290                   4
# 1466          42           9991        21457                   4
# 1467          87           6142         5174                   1
# 1468          63           5390        13243                   2
# 1469          82           4404        10228                   2
#
#       PercentSalaryHike  TotalWorkingYears
# 0                    11                  8
# 1                    23                 10
# 2                    15                  7
# ...

# %%
for i in df_c:
    print (i)
    print(sns.distplot(df[i]))
    print("Maximum :" , df_c[i].max())
    print("Minimum :" , df_c[i].min())
    plt.show()
# Out:
# HourlyRate
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 100
# Minimum : 30
# MonthlyIncome
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 19999
# Minimum : 1009
# MonthlyRate
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 26999
# Minimum : 2094
# NumCompaniesWorked
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 9
# Minimum : 0
# PercentSalaryHike
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 25
# Minimum : 11
# TotalWorkingYears
# AxesSubplot(0.125,0.125;0.775x0.755)
# Maximum : 40
# Minimum : 0

# %% [markdown]
# we have outliers in some of our data set.

# %% [markdown]
# ### Since the dataset has a lot of string values. We will use encoding

# %%
#we'll use ordinal encoder for better visulisation.

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %% [markdown]
# ### checking correlation with the target variable

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot=True, linewidths=0.1, linecolor="black", fmt="0.2f")
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()['Attrition'].sort_values(ascending=False).drop(['Attrition']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel("Target",fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [raw]
# --The attrition rate is directly related with the over time, the more over time a person does, the more likely he is to leave the firm.
# --Then comes maritial status, it shows that people who are married are likely to have high attrition rate.
# --Distance from home and department also plays crutial role in the exit of employee.
# --Jobrole also plays important role in attrition, the better the job profile the more is employee likely to leave the company.
# ---Gender is one of the factors in Attrition, women are more st stay while men have high attrition rate.
# --Total wokring years, has inverse relationship with the Attrition, it shows that whena person has worked more years, he's less likely to leave the firm.
# --Joblevel the better the job level is the less likely is an employee to leave.
# --Monthly income, the less the income the more the employee tends to leave.
# --Age, the younger the employee is the more he's likely to leave the company.
# --Years with manager, the more the years with the manager, the less likely an emplyee has attrition rate.
# --The better Job involment and job satisfaction, the less attrition.
# --Daily rate the less daily rate the high attrition rate is.

# %% [markdown]
# # Pre-processing Pipeline

# %% [markdown]
# ## Checking Skewness

# %%
from scipy.stats import skew

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %% [markdown]
# keeping the thresh-hold value (+-0.5), down below are some columns which do not lie within this range.

# %% [raw]
# Attrition-Target variable
# BusinessTravel-categorical
# --DistanceFromHome-Continous
# JobLevel-categorical
# --MonthlyIncome-Continous
# --NumCompaniesWorked- Continous
# PerformanceRating-categorical
# StockOptionLevel-categorical
# --TotalWorkingYears-Continous
# --YearsAtCompany-Continous
# --YearsInCurrentRole-Continous
# --YearsSinceLastPromotion-Continous
# --YearsWithCurrManager-Continous

# %% [markdown]
# we will not treat skewness from categorical data, we will only treat skewness from only continous data.

# %%
df['DistanceFromHome']=np.log(df['DistanceFromHome'])
df['DistanceFromHome'].skew()
# Out:
# -0.2460041611908789

# %%
df['MonthlyIncome']=np.log(df['MonthlyIncome'])
df['MonthlyIncome'].skew()
# Out:
# 0.2861922926389174

# %%
from scipy.stats import yeojohnson

# %%
df['NumCompaniesWorked']=yeojohnson(df["NumCompaniesWorked"],0)
df['NumCompaniesWorked'].skew()
# Out:
# 0.09289622460196824

# %%
df['TotalWorkingYears']=yeojohnson(df["TotalWorkingYears"],0)
df['TotalWorkingYears'].skew()
# Out:
# -0.6221748653178674

# %%
df['YearsAtCompany']=yeojohnson(df["YearsAtCompany"],0)
df['YearsAtCompany'].skew()
# Out:
# -0.20770795300104433

# %%
df['YearsInCurrentRole']=yeojohnson(df["YearsInCurrentRole"],0)
df['YearsInCurrentRole'].skew()
# Out:
# -0.3834977403156446

# %%
df['YearsSinceLastPromotion']=yeojohnson(df["YearsSinceLastPromotion"],0)
df['YearsSinceLastPromotion'].skew()
# Out:
# 0.7188045525459852

# %%
df['YearsWithCurrManager']=yeojohnson(df["YearsWithCurrManager"],0)
df['YearsWithCurrManager'].skew()
# Out:
# -0.35768565836730937

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.246004
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286192
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %% [markdown]
# Now the data has been skewed, we'll move forward towards outliers

# %% [markdown]
# ## Checking Outliers

# %%
for i in df:
    print(i)
    print(df[i].plot.box())
    plt.show()
# Out:
# Age
# AxesSubplot(0.125,0.125;0.775x0.755)
# Attrition
# AxesSubplot(0.125,0.125;0.775x0.755)
# BusinessTravel
# AxesSubplot(0.125,0.125;0.775x0.755)
# DailyRate
# AxesSubplot(0.125,0.125;0.775x0.755)
# Department
# AxesSubplot(0.125,0.125;0.775x0.755)
# DistanceFromHome
# AxesSubplot(0.125,0.125;0.775x0.755)
# Education
# AxesSubplot(0.125,0.125;0.775x0.755)
# EducationField
# AxesSubplot(0.125,0.125;0.775x0.755)
# EmployeeCount
# AxesSubplot(0.125,0.125;0.775x0.755)
# EmployeeNumber
# AxesSubplot(0.125,0.125;0.775x0.755)
# EnvironmentSatisfaction
# AxesSubplot(0.125,0.125;0.775x0.755)
# Gender
# AxesSubplot(0.125,0.125;0.775x0.755)
# HourlyRate
# AxesSubplot(0.125,0.125;0.775x0.755)
# JobInvolvement
# AxesSubplot(0.125,0.125;0.775x0.755)
# JobLevel
# AxesSubplot(0.125,0.125;0.775x0.755)
# JobRole
# AxesSubplot(0.125,0.125;0.775x0.755)
# JobSatisfaction
# AxesSubplot(0.125,0.125;0.775x0.755)
# MaritalStatus
# AxesSubplot(0.125,0.125;0.775x0.755)
# MonthlyIncome
# ...

# %% [raw]
# TotalWorkingYears
# TrainingTimesLastYear
# YearsAtCompany
# ------There are few outliers in these dataset.

# %%
df['TotalWorkingYears'].unique()
# Out:
# array([2.19722458, 2.39789527, 2.07944154, 1.94591015, 2.56494936,
#        0.69314718, 2.89037176, 1.79175947, 1.38629436, 3.4657359 ,
#        2.63905733, 0.        , 3.29583687, 3.21887582, 3.13549422,
#        2.30258509, 2.99573227, 1.09861229, 3.17805383, 2.7080502 ,
#        2.77258872, 1.60943791, 3.40119738, 3.36729583, 3.09104245,
#        3.25809654, 3.04452244, 2.48490665, 2.83321334, 3.63758616,
#        3.66356165, 3.4339872 , 3.71357207, 2.94443898, 3.61091791,
#        3.55534806, 3.49650756, 3.52636052, 3.58351894, 3.33220451])

# %%
df['TrainingTimesLastYear'].unique()
# Out:
# array([0, 3, 2, 5, 1, 4, 6], dtype=int64)

# %%
df['YearsAtCompany'].unique()
# Out:
# array([1.94591015, 2.39789527, 0.        , 2.19722458, 1.09861229,
#        2.07944154, 0.69314718, 2.30258509, 1.79175947, 1.60943791,
#        3.25809654, 1.38629436, 2.56494936, 2.7080502 , 3.13549422,
#        2.77258872, 3.33220451, 3.09104245, 2.89037176, 2.48490665,
#        2.63905733, 3.63758616, 2.83321334, 3.04452244, 3.71357207,
#        3.21887582, 3.52636052, 2.99573227, 3.61091791, 2.94443898,
#        3.40119738, 3.4657359 , 3.49650756, 3.55534806, 3.29583687,
#        3.4339872 , 3.17805383])

# %% [raw]
# outliers should not be removed in any of the
# TotalWorkingYears
# TrainingTimesLastYear
# YearsAtCompany,
# As there might be employees with a experiance and those who have attended the Training and Those who are in company since a log time.
#
#
# Removing these outliers our data will be biased. and wont perfrom well enough in real-life senario.

# %% [markdown]
# # Making Data Set Ready For Machine Learning Models

# %% [markdown]
# ### Seprating the columns into features and target:

# %%
features=df.drop('Attrition',axis=1)
target=df["Attrition"]

# %%
features
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41             2.0       1102         2.0          0.000000          2
# 1      49             1.0        279         1.0          2.079442          1
# 2      37             2.0       1373         1.0          0.693147          2
# 3      33             1.0       1392         1.0          1.098612          4
# 4      27             2.0        591         1.0          0.693147          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36             1.0        884         1.0          3.135494          2
# 1466   39             2.0        613         1.0          1.791759          1
# 1467   27             2.0        155         1.0          1.386294          3
# 1468   49             1.0       1023         2.0          0.693147          3
# 1469   34             2.0        628         1.0          2.079442          3
#
# ...

# %%
target
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %% [markdown]
# ## Using Min-Max Scaler to scale the data:

# %% [markdown]
# As here are a lot of string values so we'll be using Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
scaler=MinMaxScaler()
scaler.fit_transform(features)
# Out:
# array([[0.54761905, 1.        , 0.71581961, ..., 0.54660257, 0.        ,
#         0.61990623],
#        [0.73809524, 0.5       , 0.12670007, ..., 0.70622674, 0.25      ,
#         0.7194374 ],
#        [0.45238095, 1.        , 0.90980673, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.21428571, 1.        , 0.03793844, ..., 0.3731143 , 0.        ,
#         0.47962493],
#        [0.73809524, 0.5       , 0.65926986, ..., 0.66087637, 0.        ,
#         0.76018753],
#        [0.38095238, 1.        , 0.37652112, ..., 0.47081783, 0.25      ,
#         0.38009377]])

# %% [markdown]
# # Building Machine Learning Models

# %% [markdown]
# ## Importing libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ### GaussianNB

# %%
gnb=GaussianNB()

# %% [markdown]
# #To find best random state

# %%
for i in range (0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    gnb.fit(features_train,target_train)
    pred_train=gnb.predict(features_train)
    pred_test=gnb.predict(features_test)
    
    print(f'At random state {i}, the training accuractarget is:  {accuracy_score(target_train,pred_train)}')
    print(f"At random state {i}, the testing accuractarget is:   {accuracy_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuractarget is:  0.8222789115646258
# At random state 0, the testing accuractarget is:   0.8299319727891157
#
#
# At random state 1, the training accuractarget is:  0.8341836734693877
# At random state 1, the testing accuractarget is:   0.8435374149659864
#
#
# At random state 2, the training accuractarget is:  0.8299319727891157
# At random state 2, the testing accuractarget is:   0.8571428571428571
#
#
# At random state 3, the training accuractarget is:  0.8163265306122449
# At random state 3, the testing accuractarget is:   0.8197278911564626
#
#
# At random state 4, the training accuractarget is:  0.8299319727891157
# At random state 4, the testing accuractarget is:   0.8129251700680272
#
#
# At random state 5, the training accuractarget is:  0.826530612244898
# At random state 5, the testing accuractarget is:   0.8163265306122449
#
#
# At random state 6, the training accuractarget is:  0.8299319727891157
# ...

# %% [markdown]
# Random State 11 is best, random state for GNB

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=11)

# %%
gnb.fit(features_train,target_train)
predgnb=gnb.predict(features_test)
print(accuracy_score(target_test,predgnb))

print(confusion_matrix(target_test,predgnb))

print(classification_report(target_test,predgnb))
# Out:
# 0.8639455782312925
# [[229  17]
#  [ 23  25]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.93      0.92       246
#          1.0       0.60      0.52      0.56        48
#
#     accuracy                           0.86       294
#    macro avg       0.75      0.73      0.74       294
# weighted avg       0.86      0.86      0.86       294

# %% [markdown]
# The accuracy score for GNB is 86%

# %% [markdown]
# ## SupportVectorClassifier

# %% [markdown]
# ### To find best random state

# %%
svc=SVC(kernel='rbf')

# %%
for i in range (0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    svc.fit(features_train,target_train)
    pred_train=svc.predict(features_train)
    pred_test=svc.predict(features_test)
    
    print(f'At random state {i}, the training accuractarget is:  {accuracy_score(target_train,pred_train)}')
    print(f"At random state {i}, the testing accuractarget is:   {accuracy_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuractarget is:  0.8401360544217688
# At random state 0, the testing accuractarget is:   0.8333333333333334
#
#
# At random state 1, the training accuractarget is:  0.8477891156462585
# At random state 1, the testing accuractarget is:   0.8027210884353742
#
#
# At random state 2, the training accuractarget is:  0.8392857142857143
# At random state 2, the testing accuractarget is:   0.8367346938775511
#
#
# At random state 3, the training accuractarget is:  0.8333333333333334
# At random state 3, the testing accuractarget is:   0.8605442176870748
#
#
# At random state 4, the training accuractarget is:  0.8350340136054422
# At random state 4, the testing accuractarget is:   0.8537414965986394
#
#
# At random state 5, the training accuractarget is:  0.8401360544217688
# At random state 5, the testing accuractarget is:   0.8333333333333334
#
#
# At random state 6, the training accuractarget is:  0.8392857142857143
# ...

# %% [markdown]
# Random State 15 is best, random state for SVC

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=15)

# %%
svc.fit(features_train,target_train)
svc.score(features_train,target_train)
predsvc=svc.predict(features_test)

print(accuracy_score(target_test,predsvc))
print(confusion_matrix(target_test,predsvc))
print(classification_report(target_test,predsvc))
# Out:
# 0.8605442176870748
# [[253   0]
#  [ 41   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      1.00      0.93       253
#          1.0       0.00      0.00      0.00        41
#
#     accuracy                           0.86       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.74      0.86      0.80       294

# %% [markdown]
# The accuracy score for SVC is also 86%

# %% [markdown]
# ## DecissionTreeClassifier

# %% [markdown]
# ### To find best random state

# %%
dtc=DecisionTreeClassifier()

# %%
for i in range (0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    dtc.fit(features_train,target_train)
    pred_train=dtc.predict(features_train)
    pred_test=dtc.predict(features_test)
    
    print(f'At random state {i}, the training accuractarget is:  {accuracy_score(target_train,pred_train)}')
    print(f"At random state {i}, the testing accuractarget is:   {accuracy_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuractarget is:  1.0
# At random state 0, the testing accuractarget is:   0.7551020408163265
#
#
# At random state 1, the training accuractarget is:  1.0
# At random state 1, the testing accuractarget is:   0.782312925170068
#
#
# At random state 2, the training accuractarget is:  1.0
# At random state 2, the testing accuractarget is:   0.7959183673469388
#
#
# At random state 3, the training accuractarget is:  1.0
# At random state 3, the testing accuractarget is:   0.7891156462585034
#
#
# At random state 4, the training accuractarget is:  1.0
# At random state 4, the testing accuractarget is:   0.7857142857142857
#
#
# At random state 5, the training accuractarget is:  1.0
# At random state 5, the testing accuractarget is:   0.782312925170068
#
#
# At random state 6, the training accuractarget is:  1.0
# At random state 6, the testing accuractarget is:   0.7959183673469388
#
#
# At random state 7, the training accuractarget is:  1.0
# ...

# %% [markdown]
# Random State 23 is best, random state for DTC

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=23)

# %%
dtc.fit(features_train,target_train)
dtc.score(features_train,target_train)
preddtc=dtc.predict(features_test)

print(accuracy_score(target_test,preddtc))
print(confusion_matrix(target_test,preddtc))
print(classification_report(target_test,preddtc))
# Out:
# 0.8095238095238095
# [[219  27]
#  [ 29  19]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.89       246
#          1.0       0.41      0.40      0.40        48
#
#     accuracy                           0.81       294
#    macro avg       0.65      0.64      0.65       294
# weighted avg       0.81      0.81      0.81       294

# %% [markdown]
# The accuracy score for DTC is 82%

# %% [markdown]
# ## KNeighboursClassifier()

# %% [markdown]
# ### To find best random state

# %%
knn=SVC(kernel='poly')

# %%
for i in range (0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    knn.fit(features_train,target_train)
    pred_train=knn.predict(features_train)
    pred_test=knn.predict(features_test)
    
    print(f'At random state {i}, the training accuractarget is:  {accuracy_score(target_train,pred_train)}')
    print(f"At random state {i}, the testing accuractarget is:   {accuracy_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuractarget is:  0.8401360544217688
# At random state 0, the testing accuractarget is:   0.8333333333333334
#
#
# At random state 1, the training accuractarget is:  0.8477891156462585
# At random state 1, the testing accuractarget is:   0.8027210884353742
#
#
# At random state 2, the training accuractarget is:  0.8392857142857143
# At random state 2, the testing accuractarget is:   0.8367346938775511
#
#
# At random state 3, the training accuractarget is:  0.8333333333333334
# At random state 3, the testing accuractarget is:   0.8605442176870748
#
#
# At random state 4, the training accuractarget is:  0.8350340136054422
# At random state 4, the testing accuractarget is:   0.8537414965986394
#
#
# At random state 5, the training accuractarget is:  0.8401360544217688
# At random state 5, the testing accuractarget is:   0.8333333333333334
#
#
# At random state 6, the training accuractarget is:  0.8392857142857143
# ...

# %% [markdown]
# Random State 26 is best, random state for KNN

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=26)

# %%
knn.fit(features_train,target_train)
knn.score(features_train,target_train)
predknn=knn.predict(features_test)

print(accuracy_score(target_test,predknn))
print(confusion_matrix(target_test,predknn))
print(classification_report(target_test,predknn))
# Out:
# 0.8877551020408163
# [[261   0]
#  [ 33   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94       261
#          1.0       0.00      0.00      0.00        33
#
#     accuracy                           0.89       294
#    macro avg       0.44      0.50      0.47       294
# weighted avg       0.79      0.89      0.83       294

# %% [markdown]
# The accuracy score for Knn is 88%

# %% [markdown]
# ### chosen model

# %% [markdown]
# KNN is the better model incomparision if all the other models, as it has the highest accuracy score, hence it will be the chosen model

# %% [markdown]
# ## Cross Validation of the model:

# %%
Train_accuracy=accuracy_score(target_train,pred_train)
Test_accuracy=accuracy_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(knn,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.8387755102040817 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# At cross fold 3 the cv score is 0.8387755102040816 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# At cross fold 4 the cv score is 0.8387761373060064 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# At cross fold 5 the cv score is 0.8387755102040817 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# At cross fold 6 the cv score is 0.8387755102040817 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# At cross fold 7 the cv score is 0.8387755102040816 and accuracy score for training is 0.826530612244898 and accuracy for the testing is 0.8877551020408163
#
#
# ...

# %% [markdown]
# the accuracy score and cv_score is same for all. so cv=8 is selected.

# %%
cv_score=cross_val_score(knn,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.8387755102040817

# %% [markdown]
# ## Ensemble technique:

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBCModel = GradientBoostingClassifier(n_estimators=100,max_depth=3,random_state=33) 
GBCModel.fit(features_train, target_train)

print('GBCModel Train Score is : ' , GBCModel.score(features_train, target_train))
print('GBCModel Test Score is : ' , GBCModel.score(features_test, target_test))
# Out:
# GBCModel Train Score is :  0.9583333333333334
# GBCModel Test Score is :  0.9013605442176871

# %% [markdown]
# the model is performing well, train score is 95%, while test score is 90%

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
target_pred = GBCModel.predict(features_test)

# %%
CM = confusion_matrix(target_test, target_pred)
print('Confusion Matrix is : \n', CM)


sns.heatmap(CM,cmap='PuBu')
plt.show()
# Out:
# Confusion Matrix is :
#  [[252   9]
#  [ 20  13]]

# %% [raw]
# total positive values is 252-(correctly predicted by model)
# false positive values is 9
# false negative values is 20
# total negative values is 13
# This shows that the model is working good.

# %% [raw]
# ### Saving the model
#
# import pickle
# filename="IBM_HR_Attrition_Rate_Analytics"
# pickle.dump(rf, open(filename,'wb'))
#
# loaded_model = pickle.load(open("IBM_HR_Attrition_Rate_Analytics",'rb'))
# result=loaded_model.score(feature_test,target_test)
# print(result)
#
# conclusion = pd.DataFrame([loaded_model.predict(feature_test)[:],pred_decision[:]],index=["Predicted","Orignal"])
# conclusion

# %% [markdown]
# ## Concluding Remarks

# %% [raw]
# The analysis shows that the:-
# Over time, Distance, have direct relationship with the attriation
# while, Total working years, Job level, Monthly income, Age have inverse relationship with the attrition rate.
# KNN is the best model with highest accuracy rate of 88%, hence being chosen model.
# cross-val score is 83%.
# this shows that our model is performing good.
